# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Preparing the data

# %%
x = np.linspace(0, 10*np.pi, num=1000)
e = np.random.normal(scale=10.0, size=x.size)
y = 65.0 + 1.8*x + 40*np.cos(x) + e

# %%
plt.scatter(x, y);

# %% [markdown]
# # PyTorch gradient calculation example
#
# Useful docs from the official documentation:
#
# https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html
#
# https://pytorch.org/tutorials/beginner/introyt/autogradyt_tutorial.html
#
# https://pytorch.org/tutorials/beginner/basics/tensorqs_tutorial.html

# %%
import torch

# %%
xt = torch.tensor(x)
yt = torch.tensor(y)
learning_rate = 1e-2

# %%
plt.scatter(xt, yt);

# %%
## A simple linear regression model
w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(1.0, requires_grad=True)
def model(x):
    return w * x + b

## Compute prediction error
def loss_fn(prediction, y):
    return ((prediction-y)**2).mean()

prediction = model(xt)
loss = loss_fn(prediction, yt)

## Backpropagation
loss.backward()
with torch.no_grad():
    w -= w.grad * learning_rate
    b -= b.grad * learning_rate
    # Set the gradients to zero
    w.grad.zero_()
    b.grad.zero_()

# %%
w, b
# Out:
# (tensor(26.6758, requires_grad=True), tensor(2.5488, requires_grad=True))

# %% [markdown]
# # TensorFlow gradient calculation example
#
# Useful docs from the official documentation:
#
# https://www.tensorflow.org/guide/basic_training_loops
#
# https://www.tensorflow.org/guide/autodiff
#
# https://www.tensorflow.org/api_docs/python/tf/Variable
#
# https://www.tensorflow.org/api_docs/python/tf/Tensor

# %%
import tensorflow as tf
# Out:
# 2024-08-04 21:24:27.696759: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-04 21:24:27.758261: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-04 21:24:27.774578: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-04 21:24:27.880558: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-04 21:24:28.727682: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
xt = tf.constant(x, dtype=tf.float32)
yt = tf.constant(y, dtype=tf.float32)
learning_rate = 1e-2
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722831871.399291   84423 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1722831871.503977   84423 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1722831871.504015   84423 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1722831871.506864   84423 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1722831871.506897   84423 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1722831871.506910   84423 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1722831871.614270   84423 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1722831871.614321   84423 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-08-04 21:24:31.614329: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1722831871.614355   84423 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-08-04 21:24:31.614669: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1928 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
plt.scatter(xt, yt);

# %%
## A simple linear regression model
w = tf.Variable(1.0, trainable=True)
b = tf.Variable(1.0, trainable=True)
def model(x):
    return w * x + b

## Compute prediction error
def loss_fn(prediction, y):
    return tf.reduce_mean(tf.square(prediction-y))

with tf.GradientTape() as tape:
    prediction = model(xt)
    loss = loss_fn(prediction, yt)

## Backpropagation
dw, db = tape.gradient(loss, [w, b])
w.assign_sub(learning_rate * dw)
b.assign_sub(learning_rate * db)

# %%
w, b
# Out:
# (<tf.Variable 'Variable:0' shape=() dtype=float32, numpy=26.675842>,
#  <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=2.54878>)

# %% [markdown]
# # JAX gradient calculation example
#
# Useful docs from the official documentation:
#
# https://jax.readthedocs.io/en/latest/jax-101/01-jax-basics.html
#
# https://jax.readthedocs.io/en/latest/jax-101/04-advanced-autodiff.html

# %%
import jax
import jax.numpy as jnp

# %%
xt = jnp.array(x)
yt = jnp.array(y)
learning_rate = 1e-2

# %%
plt.scatter(x, y);

# %%
# A simple linear regression model
model_parameters = jnp.array([1., 1.])
def model(theta, x):
    w, b = theta
    return w * x + b

# Function to compute prediction error
def loss_fn(model_parameters, x, y):
    prediction = model(model_parameters, x)
    return jnp.mean((prediction-y)**2)

# Backpropagation
grads_fn = jax.grad(loss_fn)
grads = grads_fn(model_parameters, xt, yt)
model_parameters -= learning_rate * grads

# %%
model_parameters
# Out:
# Array([26.288193 ,  2.5239797], dtype=float32)
